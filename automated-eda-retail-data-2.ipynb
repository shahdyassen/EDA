# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import os
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Input DataSet

# %%
def file_type():
    while True:
        try:
            path = input('Please Enter The DataSet Path and Extension: ')

            if path.endswith(('.csv', '.xlsx')):
                file_name, file_extension = os.path.splitext(path)
                file_name = 'The name of the file: ' + file_name
                file_extension = 'The extension of the file: ' + file_extension
                print(file_name + '\n' + file_extension)

                data = pd.read_csv(path)
                return data

            else:
                print('File Extension must be .xlsx or .csv')

        except FileNotFoundError:
            print('We Can’t Find This File !!!')


data = file_type()
# print(data)
# Out:
# Please Enter The DataSet Path and Extension:  ../input/retaildataset/Features data set.csv
# The name of the file: ../input/retaildataset/Features data set
# The extension of the file: .csv

# %% [markdown]
# ## Exploratory Data Anlaysis For Entire DataSet

# %%
def EDA(data):

    print('\nExploratory Data Analysis For Entire Dataset: ')
    print('---------------------------------------------------------------------------------')

    print('Number of Rows: ', data.shape[0])
    print('Number of Features: ', data.shape[1])
    print('---------------------------------------------------------------------------------')

    print('SubSet of Data:\n ', data.head().to_string())
    print('---------------------------------------------------------------------------------')

    print('\nData Information: ')
    print(data.info())
    print('---------------------------------------------------------------------------------')

    print('\nData Describe:\n ', data.describe())
    print('---------------------------------------------------------------------------------')

    print('\nColumns Names: ')
    print(data.columns)
    print('---------------------------------------------------------------------------------')

    # Null Values
    print('\nNull Values :\n', data.isnull().any())
    print('Number of Null Values :\n', data.isnull().sum())
    print('---------------------------------------------------------------------------------')

    # Duplicated Values
    print('\nDuplicated Values : ')
    print(data.duplicated().sum())
    print('---------------------------------------------------------------------------------')

    # Variables Types
    print('\nVariables Types : ')
    numeric_columns = list(data.select_dtypes(include=['int64', 'float64']).columns.values)
    print('Number of Numerical Variables : ', len(numeric_columns))
    categorical_columns = list(data.select_dtypes(include=['object']).columns.values)
    print('Number of Categorical Variables : ', len(categorical_columns))
    print('---------------------------------------------------------------------------------')

    # Data Correlation
    print('\nData Correlation : ')
    print(data.corr())
    print('---------------------------------------------------------------------------------')

    # Data Cleaning

    # Drop missing values
    data.dropna(inplace=True, axis=0)
    print('\nData After Drop missing Values :')
    print(data.shape)
    print('---------------------------------------------------------------------------------')

    # Drop Duplicated Values
    data.drop_duplicates(inplace=True)
    print('\nData After Drop Duplicated Values :')
    print(data.shape)
    print('---------------------------------------------------------------------------------')

    
print(EDA(data))
# Out:
# Exploratory Data Analysis For Entire Dataset:
# ---------------------------------------------------------------------------------
# Number of Rows:  8190
# Number of Features:  12
# ---------------------------------------------------------------------------------
# SubSet of Data:
#      Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0      1  05/02/2010        42.31       2.572        NaN        NaN        NaN        NaN        NaN  211.096358         8.106      False
# 1      1  12/02/2010        38.51       2.548        NaN        NaN        NaN        NaN        NaN  211.242170         8.106       True
# 2      1  19/02/2010        39.93       2.514        NaN        NaN        NaN        NaN        NaN  211.289143         8.106      False
# 3      1  26/02/2010        46.63       2.561        NaN        NaN        NaN        NaN        NaN  211.319643         8.106      False
# 4      1  05/03/2010        46.50       2.625        NaN        NaN        NaN        NaN        NaN  211.350143         8.106      False
# ---------------------------------------------------------------------------------
#
# Data Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB
# None
# ---------------------------------------------------------------------------------
#
# Data Describe:
#                Store  Temperature   Fuel_Price      MarkDown1      MarkDown2  \
# count  8190.000000  8190.000000  8190.000000    4032.000000    2921.000000
# mean     23.000000    59.356198     3.405992    7032.371786    3384.176594
# std      12.987966    18.678607     0.431337    9262.747448    8793.583016
# min       1.000000    -7.290000     2.472000   -2781.450000    -265.760000
# 25%      12.000000    45.902500     3.041000    1577.532500      68.880000
# 50%      23.000000    60.710000     3.513000    4743.580000     364.570000
# 75%      34.000000    73.880000     3.743000    8923.310000    2153.350000
# max      45.000000   101.950000     4.468000  103184.980000  104519.540000
#
#            MarkDown3     MarkDown4      MarkDown5          CPI  Unemployment
# count    3613.000000   3464.000000    4050.000000  7605.000000   7605.000000
# mean     1760.100180   3292.935886    4132.216422   172.460809      7.826821
# std     11276.462208   6792.329861   13086.690278    39.738346      1.877259
# min      -179.260000      0.220000    -185.170000   126.064000      3.684000
# 25%         6.600000    304.687500    1440.827500   132.364839      6.634000
# 50%        36.260000   1176.425000    2727.135000   182.764003      7.806000
# 75%       163.150000   3310.007500    4832.555000   213.932412      8.567000
# max    149483.310000  67474.850000  771448.100000   228.976456     14.313000
# ---------------------------------------------------------------------------------
#
# Columns Names:
# Index(['Store', 'Date', 'Temperature', 'Fuel_Price', 'MarkDown1', 'MarkDown2',
#        'MarkDown3', 'MarkDown4', 'MarkDown5', 'CPI', 'Unemployment',
#        'IsHoliday'],
#       dtype='object')
# ---------------------------------------------------------------------------------
#
# Null Values :
#  Store           False
# Date            False
# Temperature     False
# Fuel_Price      False
# MarkDown1        True
# MarkDown2        True
# MarkDown3        True
# MarkDown4        True
# MarkDown5        True
# CPI              True
# Unemployment     True
# IsHoliday       False
# dtype: bool
# Number of Null Values :
#  Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64
# ---------------------------------------------------------------------------------
#
# Duplicated Values :
# 0
# ---------------------------------------------------------------------------------
#
# Variables Types :
# Number of Numerical Variables :  10
# Number of Categorical Variables :  1
# ---------------------------------------------------------------------------------
#
# Data Correlation :
#                      Store  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# Store         1.000000e+00    -0.020566    0.066682  -0.136967  -0.044223
# Temperature  -2.056605e-02     1.000000    0.101354  -0.124979  -0.321888
# Fuel_Price    6.668205e-02     0.101354    1.000000   0.066122  -0.193461
# MarkDown1    -1.369671e-01    -0.124979    0.066122   1.000000   0.021289
# MarkDown2    -4.422331e-02    -0.321888   -0.193461   0.021289   1.000000
# MarkDown3    -3.327926e-02    -0.077552   -0.057168  -0.089841  -0.053555
# MarkDown4    -5.173997e-03    -0.064194   -0.008546   0.810455  -0.046595
# MarkDown5    -1.196994e-02    -0.003241   -0.021926   0.085967  -0.008166
# CPI          -2.092824e-01     0.164426   -0.186696  -0.044327  -0.044896
# Unemployment  2.211525e-01     0.150890   -0.033360   0.020501  -0.001692
# IsHoliday    -4.186667e-16    -0.161906   -0.078238   0.152621   0.299448
#
#               MarkDown3  MarkDown4  MarkDown5       CPI  Unemployment  \
# Store         -0.033279  -0.005174  -0.011970 -0.209282      0.221153
# Temperature   -0.077552  -0.064194  -0.003241  0.164426      0.150890
# Fuel_Price    -0.057168  -0.008546  -0.021926 -0.186696     -0.033360
# MarkDown1     -0.089841   0.810455   0.085967 -0.044327      0.020501
# MarkDown2     -0.053555  -0.046595  -0.008166 -0.044896     -0.001692
# MarkDown3      1.000000  -0.062785  -0.016026 -0.020166     -0.003464
# MarkDown4     -0.062785   1.000000   0.042952 -0.053868      0.021905
# MarkDown5     -0.016026   0.042952   1.000000  0.001526      0.031847
# CPI           -0.020166  -0.053868   0.001526  1.000000     -0.303110
# Unemployment  -0.003464   0.021905   0.031847 -0.303110      1.000000
# IsHoliday      0.445224   0.134841  -0.024630  0.001008     -0.002644
#
#                  IsHoliday
# Store        -4.186667e-16
# Temperature  -1.619056e-01
# Fuel_Price   -7.823797e-02
# MarkDown1     1.526209e-01
# MarkDown2     2.994476e-01
# MarkDown3     4.452239e-01
# MarkDown4     1.348406e-01
# MarkDown5    -2.462956e-02
# CPI           1.008430e-03
# Unemployment -2.644393e-03
# IsHoliday     1.000000e+00
# ---------------------------------------------------------------------------------
#
# Data After Drop missing Values :
# (2069, 12)
# ---------------------------------------------------------------------------------
#
# Data After Drop Duplicated Values :
# (2069, 12)
# ---------------------------------------------------------------------------------
# None

# %% [markdown]
# ## EDA For Numerical Features

# %%
def NumericalDataAnalysis(column):
    # Columns Exploration
    print("\nDescription of " + column)
    print("----------------------------------------------------------------------------")
    print(data[column].describe())

    # Subset of column values
    print('\nSubset values of' + column)
    print("----------------------------------------------------------------------------")
    print(data[column].head())
    
    
    # Statistical Values
    print("\nStatistical values of " + column)
    print("----------------------------------------------------------------------------")
    print('Minimum : ', data[column].min())
    print('Maximum : ', data[column].max())
    print('Mean value : ', data[column].mean())
    print('Median value : ', data[column].median())
    print('Standard deviation : ', data[column].std())

    # Null Values
    print('\nNull Values of ' + column)
    print("----------------------------------------------------------------------------")
    print('Null values : ', data[column].isnull().any())
    print('Null values : ', data[column].isnull().sum().sum())

    # Duplicated Values
    print('\nDuplicated Values of ' + column)
    print("----------------------------------------------------------------------------")
    print('Duplicated Values : ', data[column].duplicated().sum())

    # Quartiles
    print("\nQuartile of " + column)
    print("----------------------------------------------------------------------------")
    Q1 = data[column].quantile(q=0.25)
    Q3 = data[column].quantile(q=0.75)
    print('1st Quartile (Q1) is: ', Q1)
    print('3st Quartile (Q3) is: ', Q3)
    print('Interquartile range (IQR) is ', stats.iqr(data[column]))

    # outliers
    print("\nOutlier detection from Interquartile range (IQR) " + column)
    print("----------------------------------------------------------------------------")
    L_outliers = Q1 - 1.5 * (Q3 - Q1)
    U_outliers = Q3 + 1.5 * (Q3 - Q1)
    print('Lower outliers range: ', L_outliers)
    print('Upper outliers range: ', U_outliers)
    print('Number of outliers in upper : ', data[data[column] > U_outliers][column].count())
    print('Number of outliers in lower : ', data[data[column] < L_outliers][column].count())
    print('% of Outlier in upper: ', round(data[data[column] > U_outliers][column].count() * 100 / len(data)), '%')
    print('% of Outlier in lower: ', round(data[data[column] < L_outliers][column].count() * 100 / len(data)), '%')
    
    


    # boxplot
    plt.figure()
    print("\nBoxPlot of " + column)
    print("----------------------------------------------------------------------------")
    ax = sns.boxplot(x=data[column])
    plt.show()

    # dist plot
    plt.figure()
    print("\ndist plot of " + column)
    print("----------------------------------------------------------------------------")
    sns.displot(data[column])
    plt.show()

    # histogram
    plt.figure()
    print("\nHistogram of " + column)
    print("----------------------------------------------------------------------------")
    sns.displot(data[column], kde=False, color='red')
    plt.show()

    # Plotting mean, median and mode
    plt.figure()
    print("\nHistogram with mean, median and mode of " + column)
    print("----------------------------------------------------------------------------")
    mean = data[column].mean()
    median = data[column].median()
    mode = data[column].mode()

    print('Mean: ', mean, '\nMedian: ', median, '\nMode: ', mode[0])
    plt.hist(data[column], bins=100, color='lightblue')  # Plot the histogram
    plt.axvline(mean, color='green',
                label='Mean')  # Draw lines on the plot for mean median and the two modes we have in GRE Score
    plt.axvline(median, color='blue', label='Median')
    plt.axvline(mode[0], color='red', label='Mode1')
    plt.legend()
    plt.show()

    # Skewness
    print("\nSkewness of " + column)
    print("----------------------------------------------------------------------------")
    print(data[column].skew())

    print('\nThis Column is Finished !!\n Let’s start a new one\n')


# categorical_columns = list(data.select_dtypes(include=['object']).columns.values)
# print('Number of Categorical Variables : ', len(categorical_columns))

# for i in categorical_columns:
#     _labelEncoding(i)

    
numerical_data = data.select_dtypes(include=['float64', 'int64'])
numeric_columns = list(numerical_data.columns.values)
print('The Number of Numerical Columns: ', len(numeric_columns))

print('\n Numerical Columns Exploration : ')
for x in numeric_columns:
    NumericalDataAnalysis(x)
# Out:
# The Number of Numerical Columns:  10
#
#  Numerical Columns Exploration :
#
# Description of Store
# ----------------------------------------------------------------------------
# count    2069.000000
# mean       20.386660
# std        12.076174
# min         1.000000
# 25%        10.000000
# 50%        20.000000
# 75%        29.000000
# max        45.000000
# Name: Store, dtype: float64
#
# Subset values ofStore
# ----------------------------------------------------------------------------
# 92    1
# 93    1
# 94    1
# 95    1
# 96    1
# Name: Store, dtype: int64
#
# Statistical values of Store
# ----------------------------------------------------------------------------
# Minimum :  1
# Maximum :  45
# Mean value :  20.386660222329628
# Median value :  20.0
# Standard deviation :  12.076174086673007
#
# Null Values of Store
# ----------------------------------------------------------------------------
# Null values :  False
# Null values :  0
#
# Duplicated Values of Store
# ----------------------------------------------------------------------------
# Duplicated Values :  2024
#
# Quartile of Store
# ----------------------------------------------------------------------------
# 1st Quartile (Q1) is:  10.0
# 3st Quartile (Q3) is:  29.0
# Interquartile range (IQR) is  19.0
#
# Outlier detection from Interquartile range (IQR) Store
# ----------------------------------------------------------------------------
# Lower outliers range:  -18.5
# Upper outliers range:  57.5
# Number of outliers in upper :  0
# Number of outliers in lower :  0
# % of Outlier in upper:  0 %
# % of Outlier in lower:  0 %
#
# BoxPlot of Store
# ----------------------------------------------------------------------------
# dist plot of Store
# ----------------------------------------------------------------------------
# Histogram of Store
# ----------------------------------------------------------------------------
# Histogram with mean, median and mode of Store
# ----------------------------------------------------------------------------
# Mean:  20.386660222329628
# Median:  20.0
# Mode:  20
# Skewness of Store
# ----------------------------------------------------------------------------
# 0.22951250330849893
#
# This Column is Finished !!
#  Let’s start a new one
#
#
# Description of Temperature
# ----------------------------------------------------------------------------
# count    2069.000000
# mean       52.516979
# std        18.483053
# min        -7.290000
# 25%        38.100000
# 50%        51.420000
# 75%        66.610000
# max        95.910000
# Name: Temperature, dtype: float64
#
# Subset values ofTemperature
# ----------------------------------------------------------------------------
# 92    59.11
# 93    62.25
# 94    60.14
# 95    48.91
# 96    43.93
# Name: Temperature, dtype: float64
#
# Statistical values of Temperature
# ----------------------------------------------------------------------------
# Minimum :  -7.29
# Maximum :  95.91
# Mean value :  52.51697921701305
# Median value :  51.42
# Standard deviation :  18.48305287626327
#
# Null Values of Temperature
# ----------------------------------------------------------------------------
# Null values :  False
# Null values :  0
#
# Duplicated Values of Temperature
# ----------------------------------------------------------------------------
# Duplicated Values :  490
#
# Quartile of Temperature
# ----------------------------------------------------------------------------
# 1st Quartile (Q1) is:  38.1
# 3st Quartile (Q3) is:  66.61
# Interquartile range (IQR) is  28.509999999999998
#
# Outlier detection from Interquartile range (IQR) Temperature
# ----------------------------------------------------------------------------
# Lower outliers range:  -4.664999999999999
# Upper outliers range:  109.375
# Number of outliers in upper :  0
# Number of outliers in lower :  3
# % of Outlier in upper:  0 %
# % of Outlier in lower:  0 %
#
# BoxPlot of Temperature
# ----------------------------------------------------------------------------
# dist plot of Temperature
# ----------------------------------------------------------------------------
# Histogram of Temperature
# ----------------------------------------------------------------------------
# Histogram with mean, median and mode of Temperature
# ----------------------------------------------------------------------------
# Mean:  52.51697921701305
# Median:  51.42
# Mode:  52.27
# Skewness of Temperature
# ----------------------------------------------------------------------------
# 0.030200972727197472
#
# This Column is Finished !!
#  Let’s start a new one
#
#
# Description of Fuel_Price
# ----------------------------------------------------------------------------
# count    2069.000000
# mean        3.600298
# std         0.279335
# min         2.872000
# 25%         3.409000
# 50%         3.610000
# 75%         3.796000
# max         4.301000
# Name: Fuel_Price, dtype: float64
#
# Subset values ofFuel_Price
# ----------------------------------------------------------------------------
# 92    3.297
# 93    3.308
# 94    3.236
# 95    3.172
# 96    3.158
# Name: Fuel_Price, dtype: float64
#
# Statistical values of Fuel_Price
# ----------------------------------------------------------------------------
# Minimum :  2.872
# Maximum :  4.301
# Mean value :  3.6002982116964715
# Median value :  3.61
# Standard deviation :  0.2793347037052369
#
# Null Values of Fuel_Price
# ----------------------------------------------------------------------------
# Null values :  False
# Null values :  0
#
# Duplicated Values of Fuel_Price
# ----------------------------------------------------------------------------
# Duplicated Values :  1659
#
# Quartile of Fuel_Price
# ----------------------------------------------------------------------------
# 1st Quartile (Q1) is:  3.409
# 3st Quartile (Q3) is:  3.796
# Interquartile range (IQR) is  0.387
#
# Outlier detection from Interquartile range (IQR) Fuel_Price
# ----------------------------------------------------------------------------
# Lower outliers range:  2.8285
# Upper outliers range:  4.3765
# Number of outliers in upper :  0
# Number of outliers in lower :  0
# % of Outlier in upper:  0 %
# % of Outlier in lower:  0 %
#
# BoxPlot of Fuel_Price
# ----------------------------------------------------------------------------
# dist plot of Fuel_Price
# ----------------------------------------------------------------------------
# Histogram of Fuel_Price
# ----------------------------------------------------------------------------
# Histogram with mean, median and mode of Fuel_Price
# ----------------------------------------------------------------------------
# Mean:  3.6002982116964715
# Median:  3.61
# Mode:  3.417
# Skewness of Fuel_Price
# ----------------------------------------------------------------------------
# -0.10911919085354448
#
# This Column is Finished !!
#  Let’s start a new one
#
#
# Description of MarkDown1
# ----------------------------------------------------------------------------
# count      2069.000000
# mean       9717.665297
# std       11377.636869
# min        -563.900000
# 25%        3542.800000
# 50%        6397.720000
# 75%       11265.620000
# max      103184.980000
# Name: MarkDown1, dtype: float64
#
# Subset values ofMarkDown1
# ----------------------------------------------------------------------------
# 92    10382.90
# 93     6074.12
# 94      410.31
# 95     5629.51
# 96     4640.65
# Name: MarkDown1, dtype: float64
#
# Statistical values of MarkDown1
# ----------------------------------------------------------------------------
# Minimum :  -563.9
# Maximum :  103184.98
# Mean value :  9717.665297245047
# Median value :  6397.72
# Standard deviation :  11377.63686909601
#
# Null Values of MarkDown1
# ----------------------------------------------------------------------------
# Null values :  False
# Null values :  0
#
# Duplicated Values of MarkDown1
# ----------------------------------------------------------------------------
# Duplicated Values :  0
#
# Quartile of MarkDown1
# ----------------------------------------------------------------------------
# 1st Quartile (Q1) is:  3542.8
# 3st Quartile (Q3) is:  11265.62
# Interquartile range (IQR) is  7722.820000000001
#
# Outlier detection from Interquartile range (IQR) MarkDown1
# ----------------------------------------------------------------------------
# Lower outliers range:  -8041.430000000001
# Upper outliers range:  22849.850000000002
# Number of outliers in upper :  168
# Number of outliers in lower :  0
# % of Outlier in upper:  8 %
# % of Outlier in lower:  0 %
#
# BoxPlot of MarkDown1
# ----------------------------------------------------------------------------
# dist plot of MarkDown1
# ----------------------------------------------------------------------------
# Histogram of MarkDown1
# ----------------------------------------------------------------------------
# Histogram with mean, median and mode of MarkDown1
# ----------------------------------------------------------------------------
# Mean:  9717.665297245047
# Median:  6397.72
# Mode:  -563.9
# Skewness of MarkDown1
# ----------------------------------------------------------------------------
# 3.4729261094267265
#
# This Column is Finished !!
#  Let’s start a new one
#
#
# Description of MarkDown2
# ----------------------------------------------------------------------------
# count      2069.000000
# mean       4426.859778
# std       10154.658061
# min        -265.760000
# 25%          67.990000
# 50%         404.610000
# 75%        3900.310000
# max      104519.540000
# Name: MarkDown2, dtype: float64
#
# Subset values ofMarkDown2
# ----------------------------------------------------------------------------
# 92    6115.67
# 93     254.39
# 94      98.00
# 95      68.00
# 96      19.00
# Name: MarkDown2, dtype: float64
#
# Statistical values of MarkDown2
# ----------------------------------------------------------------------------
# Minimum :  -265.76
# Maximum :  104519.54
# Mean value :  4426.859777670373
# Median value :  404.61
# Standard deviation :  10154.658061111943
#
# Null Values of MarkDown2
# ----------------------------------------------------------------------------
# Null values :  False
# Null values :  0
#
# Duplicated Values of MarkDown2
# ----------------------------------------------------------------------------
# Duplicated Values :  123
#
# Quartile of MarkDown2
# ----------------------------------------------------------------------------
# 1st Quartile (Q1) is:  67.99
# 3st Quartile (Q3) is:  3900.31
# Interquartile range (IQR) is  3832.32
#
# Outlier detection from Interquartile range (IQR) MarkDown2
# ----------------------------------------------------------------------------
# Lower outliers range:  -5680.490000000001
# Upper outliers range:  9648.79
# Number of outliers in upper :  253
# Number of outliers in lower :  0
# % of Outlier in upper:  12 %
# % of Outlier in lower:  0 %
#
# BoxPlot of MarkDown2
# ----------------------------------------------------------------------------
# dist plot of MarkDown2
# ----------------------------------------------------------------------------
# Histogram of MarkDown2
# ----------------------------------------------------------------------------
# Histogram with mean, median and mode of MarkDown2
# ----------------------------------------------------------------------------
# Mean:  4426.859777670373
# Median:  404.61
# Mode:  0.03
# Skewness of MarkDown2
# ----------------------------------------------------------------------------
# 4.206809461145528
#
# This Column is Finished !!
#  Let’s start a new one
#
#
# Description of MarkDown3
# ----------------------------------------------------------------------------
# count      2069.000000
# mean       2247.535911
# std       13305.985612
# min        -179.260000
# 25%           5.840000
# 50%          34.100000
# 75%         137.990000
# max      149483.310000
# Name: MarkDown3, dtype: float64
#
# Subset values ofMarkDown3
# ----------------------------------------------------------------------------
# 92      215.07
# 93       51.98
# 94    55805.51
# 95     1398.11
# 96      105.02
# Name: MarkDown3, dtype: float64
#
# Statistical values of MarkDown3
# ----------------------------------------------------------------------------
# Minimum :  -179.26
# Maximum :  149483.31
# Mean value :  2247.5359110681493
# Median value :  34.1
# Standard deviation :  13305.98561231841
#
# Null Values of MarkDown3
# ----------------------------------------------------------------------------
# Null values :  False
# Null values :  0
#
# Duplicated Values of MarkDown3
# ----------------------------------------------------------------------------
# Duplicated Values :  335
#
# Quartile of MarkDown3
# ----------------------------------------------------------------------------
# 1st Quartile (Q1) is:  5.84
# 3st Quartile (Q3) is:  137.99
# Interquartile range (IQR) is  132.15
#
# Outlier detection from Interquartile range (IQR) MarkDown3
# ----------------------------------------------------------------------------
# Lower outliers range:  -192.38500000000002
# Upper outliers range:  336.21500000000003
# Number of outliers in upper :  271
# Number of outliers in lower :  0
# % of Outlier in upper:  13 %
# % of Outlier in lower:  0 %
#
# BoxPlot of MarkDown3
# ----------------------------------------------------------------------------
# dist plot of MarkDown3
# ----------------------------------------------------------------------------
# Histogram of MarkDown3
# ----------------------------------------------------------------------------
# Histogram with mean, median and mode of MarkDown3
# ----------------------------------------------------------------------------
# Mean:  2247.5359110681493
# Median:  34.1
# Mode:  1.0
# Skewness of MarkDown3
# ----------------------------------------------------------------------------
# 7.185372954518369
#
# This Column is Finished !!
#  Let’s start a new one
#
#
# Description of MarkDown4
# ----------------------------------------------------------------------------
# count     2069.000000
# mean      4213.162687
# std       8359.765985
# min          0.460000
# 25%        404.050000
# 50%       1401.230000
# 75%       3834.440000
# max      67474.850000
# Name: MarkDown4, dtype: float64
#
# Subset values ofMarkDown4
# ----------------------------------------------------------------------------
# 92    2406.62
# 93     427.39
# 94       8.00
# 95    2084.64
# 96    3639.42
# Name: MarkDown4, dtype: float64
#
# Statistical values of MarkDown4
# ----------------------------------------------------------------------------
# Minimum :  0.46
# Maximum :  67474.85
# Mean value :  4213.162687288545
# Median value :  1401.23
# Standard deviation :  8359.765984684525
#
# Null Values of MarkDown4
# ----------------------------------------------------------------------------
# Null values :  False
# Null values :  0
#
# Duplicated Values of MarkDown4
# ----------------------------------------------------------------------------
# Duplicated Values :  19
#
# Quartile of MarkDown4
# ----------------------------------------------------------------------------
# 1st Quartile (Q1) is:  404.05
# 3st Quartile (Q3) is:  3834.44
# Interquartile range (IQR) is  3430.39
#
# Outlier detection from Interquartile range (IQR) MarkDown4
# ----------------------------------------------------------------------------
# Lower outliers range:  -4741.535
# Upper outliers range:  8980.025
# Number of outliers in upper :  232
# Number of outliers in lower :  0
# % of Outlier in upper:  11 %
# % of Outlier in lower:  0 %
#
# BoxPlot of MarkDown4
# ----------------------------------------------------------------------------
# dist plot of MarkDown4
# ----------------------------------------------------------------------------
# Histogram of MarkDown4
# ----------------------------------------------------------------------------
# Histogram with mean, median and mode of MarkDown4
# ----------------------------------------------------------------------------
# Mean:  4213.162687288545
# Median:  1401.23
# Mode:  3.0
# Skewness of MarkDown4
# ----------------------------------------------------------------------------
# 3.993970963861659
#
# This Column is Finished !!
#  Let’s start a new one
#
#
# Description of MarkDown5
# ----------------------------------------------------------------------------
# count      2069.000000
# mean       5056.916061
# std       17807.168442
# min        -185.170000
# 25%        2014.840000
# 50%        3470.490000
# 75%        5674.110000
# max      771448.100000
# Name: MarkDown5, dtype: float64
#
# Subset values ofMarkDown5
# ----------------------------------------------------------------------------
# 92     6551.42
# 93     5988.57
# 94      554.92
# 95    20475.32
# 96    14461.82
# Name: MarkDown5, dtype: float64
#
# Statistical values of MarkDown5
# ----------------------------------------------------------------------------
# Minimum :  -185.17
# Maximum :  771448.1
# Mean value :  5056.916060898984
# Median value :  3470.49
# Standard deviation :  17807.16844157721
#
# Null Values of MarkDown5
# ----------------------------------------------------------------------------
# Null values :  False
# Null values :  0
#
# Duplicated Values of MarkDown5
# ----------------------------------------------------------------------------
# Duplicated Values :  3
#
# Quartile of MarkDown5
# ----------------------------------------------------------------------------
# 1st Quartile (Q1) is:  2014.84
# 3st Quartile (Q3) is:  5674.11
# Interquartile range (IQR) is  3659.2699999999995
#
# Outlier detection from Interquartile range (IQR) MarkDown5
# ----------------------------------------------------------------------------
# Lower outliers range:  -3474.0649999999987
# Upper outliers range:  11163.015
# Number of outliers in upper :  98
# Number of outliers in lower :  0
# % of Outlier in upper:  5 %
# % of Outlier in lower:  0 %
#
# BoxPlot of MarkDown5
# ----------------------------------------------------------------------------
# dist plot of MarkDown5
# ----------------------------------------------------------------------------
# Histogram of MarkDown5
# ----------------------------------------------------------------------------
# Histogram with mean, median and mode of MarkDown5
# ----------------------------------------------------------------------------
# Mean:  5056.916060898984
# Median:  3470.49
# Mode:  986.23
# Skewness of MarkDown5
# ----------------------------------------------------------------------------
# 38.858953980018825
#
# This Column is Finished !!
#  Let’s start a new one
#
#
# Description of CPI
# ----------------------------------------------------------------------------
# count    2069.000000
# mean      175.587370
# std        39.963914
# min       129.816710
# 25%       137.423897
# 50%       189.707605
# 75%       219.970560
# max       228.976456
# Name: CPI, dtype: float64
#
# Subset values ofCPI
# ----------------------------------------------------------------------------
# 92    217.998085
# 93    218.220509
# 94    218.467621
# 95    218.714733
# 96    218.961846
# Name: CPI, dtype: float64
#
# Statistical values of CPI
# ----------------------------------------------------------------------------
# Minimum :  129.8167097
# Maximum :  228.9764563
# Mean value :  175.58736959458676
# Median value :  189.7076048
# Standard deviation :  39.963914009183355
#
# Null Values of CPI
# ----------------------------------------------------------------------------
# Null values :  False
# Null values :  0
#
# Duplicated Values of CPI
# ----------------------------------------------------------------------------
# Duplicated Values :  1263
#
# Quartile of CPI
# ----------------------------------------------------------------------------
# 1st Quartile (Q1) is:  137.4238966
# 3st Quartile (Q3) is:  219.9705599
# Interquartile range (IQR) is  82.5466633
#
# Outlier detection from Interquartile range (IQR) CPI
# ----------------------------------------------------------------------------
# Lower outliers range:  13.603901649999997
# Upper outliers range:  343.79055485000004
# Number of outliers in upper :  0
# Number of outliers in lower :  0
# % of Outlier in upper:  0 %
# % of Outlier in lower:  0 %
#
# BoxPlot of CPI
# ----------------------------------------------------------------------------
# dist plot of CPI
# ----------------------------------------------------------------------------
# Histogram of CPI
# ----------------------------------------------------------------------------
# Histogram with mean, median and mode of CPI
# ----------------------------------------------------------------------------
# Mean:  175.58736959458676
# Median:  189.7076048
# Mode:  139.1226129
# Skewness of CPI
# ----------------------------------------------------------------------------
# 0.0758104643177212
#
# This Column is Finished !!
#  Let’s start a new one
#
#
# Description of Unemployment
# ----------------------------------------------------------------------------
# count    2069.000000
# mean        7.252611
# std         1.684774
# min         3.684000
# 25%         6.162000
# 50%         7.191000
# 75%         8.256000
# max        12.890000
# Name: Unemployment, dtype: float64
#
# Subset values ofUnemployment
# ----------------------------------------------------------------------------
# 92    7.866
# 93    7.866
# 94    7.866
# 95    7.866
# 96    7.866
# Name: Unemployment, dtype: float64
#
# Statistical values of Unemployment
# ----------------------------------------------------------------------------
# Minimum :  3.684
# Maximum :  12.89
# Mean value :  7.252611406476559
# Median value :  7.191
# Standard deviation :  1.6847739193633453
#
# Null Values of Unemployment
# ----------------------------------------------------------------------------
# Null values :  False
# Null values :  0
#
# Duplicated Values of Unemployment
# ----------------------------------------------------------------------------
# Duplicated Values :  1872
#
# Quartile of Unemployment
# ----------------------------------------------------------------------------
# 1st Quartile (Q1) is:  6.162
# 3st Quartile (Q3) is:  8.256
# Interquartile range (IQR) is  2.0940000000000003
#
# Outlier detection from Interquartile range (IQR) Unemployment
# ----------------------------------------------------------------------------
# Lower outliers range:  3.0209999999999995
# Upper outliers range:  11.397
# Number of outliers in upper :  57
# Number of outliers in lower :  0
# % of Outlier in upper:  3 %
# % of Outlier in lower:  0 %
#
# BoxPlot of Unemployment
# ----------------------------------------------------------------------------
# dist plot of Unemployment
# ----------------------------------------------------------------------------
# Histogram of Unemployment
# ----------------------------------------------------------------------------
# Histogram with mean, median and mode of Unemployment
# ----------------------------------------------------------------------------
# Mean:  7.252611406476559
# Median:  7.191
# Mode:  7.057
# Skewness of Unemployment
# ----------------------------------------------------------------------------
# 0.46851024471100006
#
# This Column is Finished !!
#  Let’s start a new one

# %% [markdown]
# ## EDA For Categorical Data

# %%
def CategoricalDataAnalysis(column):
    # Columns Exploration
    print("\nDescription of " + column)
    print("----------------------------------------------------------------------------")
    print(data[column].describe())

    # Subset of column values
    print('\nSubset values of ' + column)
    print("----------------------------------------------------------------------------")
    print(data[column].head())
    
    # Values count
    print('\Values Count of : ' + column)
    print("----------------------------------------------------------------------------")
    print(data[column].value_counts())
    
    # Box Plot
    sns.countplot(x=data[column], data=data)
    plt.show()

categorical_data = data.select_dtypes(include=['object'])
categorical_columns = list(categorical_data.columns.values)
print('The Number of categorical Columns : ', len(categorical_columns))

print('\n Categorical Columns Exploration : ')
for y in categorical_columns:
    CategoricalDataAnalysis(y)
# Out:
# The Number of categorical Columns :  1
#
#  Categorical Columns Exploration :
#
# Description of Date
# ----------------------------------------------------------------------------
# count           2069
# unique            70
# top       03/02/2012
# freq              43
# Name: Date, dtype: object
#
# Subset values of Date
# ----------------------------------------------------------------------------
# 92    11/11/2011
# 93    18/11/2011
# 94    25/11/2011
# 95    02/12/2011
# 96    09/12/2011
# Name: Date, dtype: object
# \Values Count of : Date
# ----------------------------------------------------------------------------
# 03/02/2012    43
# 08/02/2013    42
# 28/12/2012    41
# 30/12/2011    40
# 01/02/2013    40
#               ..
# 15/03/2013     4
# 06/04/2012     3
# 25/05/2012     2
# 18/05/2012     1
# 29/06/2012     1
# Name: Date, Length: 70, dtype: int64
